# %% [markdown]
# <a href="https://colab.research.google.com/github/MudassirABBASSi/Computer-Vision/blob/main/contourd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow
path  = "/content/images.png"
img = cv2.imread(path)

colo = cv2.cvtColor(img , cv2.COLOR_BGR2GRAY)

ret,th1 = cv2.threshold(colo,127,200,cv2.THRESH_BINARY_INV)

contours , thresh = cv2.findContours(th1,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)

cv2_imshow(img)
cv2_imshow(th1)
# cv2_imshow(continue)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>
# <PIL.Image.Image image mode=L size=275x183>

# %%
import cv2
import numpy as np

# Read the image
img = cv2.imread('/content/images.png')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Convert to binary (thresholding)
ret, thresh = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)

# Find contours
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

# Draw contours on the image
cv2.drawContours(img, contours, -1, (0, 255, 0), 2)

# for contour in contours:
#     # Get bounding box coordinates
#     x, y, w, h = cv2.boundingRect(contour)

#     # Draw rectangle (bounding box)
#     cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)
cv2.drawContours(img,contours = -1,contourIdx=-1,color=(0,255,0),thickness=2)
# Show result
cv2_imshow(img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /tmp/ipython-input-1246144046.py in <cell line: 0>()
#      21 #     # Draw rectangle (bounding box)
#      22 #     cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)
# ---> 23 cv2.drawContours(img,contours = -1,contourIdx=-1,color=(0,255,0),thickness=2)
#      24 # Show result
#      25 cv2_imshow(img)
#
# error: OpenCV(4.12.0) :-1: error: (-5:Bad argument) in function 'drawContours'
# > Overload resolution failed:
# >  - Can't parse 'contours'. Input argument doesn't provide sequence protocol
# >  - Can't parse 'contours'. Input argument doesn't provide sequence protocol

# %%
import cv2

# Read the image
img = cv2.imread('/content/images.png')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Convert to binary
ret, thresh = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)

# Find contours
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)



for cnt in contours:
  if cv2.contourArea(cnt)<100:
    x,y,w,h = cv2.boundingRect(cnt)
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>

# %%
import cv2

# Read the image
img = cv2.imread('/content/images.png')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Convert to binary
ret, thresh = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)

# Find contours
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

for contour in contours:
    # Get bounding box coordinates
    x, y, w, h = cv2.boundingRect(contour)

    # Draw rectangle (bounding box)
    cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)

# Show image with bounding boxes
cv2_imshow( img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>
