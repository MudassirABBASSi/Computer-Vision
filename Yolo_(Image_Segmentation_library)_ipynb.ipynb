# %% [markdown]
# <a href="https://colab.research.google.com/github/MudassirABBASSi/Computer-Vision/blob/main/Yolo_(Image_Segmentation_library)_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
HOME = os.getcwd()
print(HOME)
# %pip install "ultralytics<=8.3.40" supervision roboflow
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.40 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 40.9/112.6 GB disk)

# %% [markdown]
# #CLI

# %%
# !yolo task=segment mode=predict model=yolo11l-seg.pt conf=0.25 source='https://media.roboflow.com/notebooks/examples/dog.jpeg' save=True

from IPython.display import Image as IPyImage
IPyImage(filename=f'{HOME}/runs/segment/predict/dog.jpg', width=600)
# Out:
# ...
# 100% 53.5M/53.5M [00:00<00:00, 280MB/s]
# Ultralytics 8.3.40 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11l-seg summary (fused): 491 layers, 27,646,272 parameters, 0 gradients, 142.2 GFLOPs
#
# ...
# 100% 104k/104k [00:00<00:00, 45.1MB/s]
# image 1/1 /content/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 1 backpack, 200.9ms
# Speed: 15.2ms preprocess, 200.9ms inference, 629.2ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/segment/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=segment mode=predict model=YOLOv8.pt conf=0.25 source='https://media.roboflow.com/notebooks/examples/dog.jpeg' save=True

from IPython.display import Image as IPyImage
IPyImage(filename=f'{HOME}/runs/segment/predict/dog.jpg', width=600)

# %% [markdown]
# #sdk

# %%
model = ultralytics.YOLO("yolo11l-seg.pt")  # Load a segmentation model
results = model.predict(source='https://media.roboflow.com/notebooks/examples/dog.jpeg', save=True, conf=0.25)

# Display the image
IPyImage(filename=f'{HOME}/runs/segment/predict/dog.jpg', width=600)


model = ultralytics.YOLO("yolo11m-seg.pt")  # Load a segmentation model
results = model.predict(source='https://media.roboflow.com/notebooks/examples/dog.jpeg', save=True, conf=0.25)

# Display the image
IPyImage(filename=f'{HOME}/runs/segment/predict/dog.jpg', width=600)
# Out:
# Found https://media.roboflow.com/notebooks/examples/dog.jpeg locally at dog.jpeg
# image 1/1 /content/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 1 backpack, 40.7ms
# Speed: 2.1ms preprocess, 40.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/segment/predict13
#
# Found https://media.roboflow.com/notebooks/examples/dog.jpeg locally at dog.jpeg
# image 1/1 /content/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 2 backpacks, 27.1ms
# Speed: 1.8ms preprocess, 27.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/segment/predict14

# %% [markdown]
# # Tracking
# **video tracking**

# %%
pip install yt-dlp
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.9/171.9 kB 10.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 88.7 MB/s eta 0:00:00
# ...

# %%
import os
import yt_dlp
from ultralytics import YOLO

# Load YOLOv8 model
model = YOLO("yolov8m.pt")  # You can use yolov8n.pt, yolov8s.pt, etc.

# Run object tracking
results = model.track(source="/content/1.mp4", task="track", save=True)

print("Tracking complete. Check the output folder for results.")
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/1336) /content/1.mp4: 640x384 1 person, 1 couch, 25.8ms
# video 1/1 (frame 2/1336) /content/1.mp4: 640x384 1 person, 1 couch, 25.1ms
# video 1/1 (frame 3/1336) /content/1.mp4: 640x384 1 person, 1 couch, 24.5ms
# video 1/1 (frame 4/1336) /content/1.mp4: 640x384 1 person, 1 couch, 24.6ms
# video 1/1 (frame 5/1336) /content/1.mp4: 640x384 1 person, 1 couch, 24.5ms
# ...
