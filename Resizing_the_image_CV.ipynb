# %% [markdown]
# <a href="https://colab.research.google.com/github/MudassirABBASSi/Computer-Vision/blob/main/Resizing_the_image_CV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import os
from google.colab.patches import cv2_imshow

# Use absolute path to ensure the image is found
img_path = '/content/5.jpeg'
img = cv2.imread(img_path)

# Check if image was loaded successfully
if img is None:
    print(f"Error: Could not load image from {img_path}")
    print("Please check if the file exists and is a valid image format.")
else:
    print(f"Image loaded successfully. Shape: {img.shape}")
    resize = cv2.resize(img, (200,200))
    print(resize.shape)
    cv2_imshow(img)
    cv2_imshow(resize)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
# Out:
# Image loaded successfully. Shape: (290, 410, 3)
# (200, 200, 3)
# <PIL.Image.Image image mode=RGB size=410x290>
# <PIL.Image.Image image mode=RGB size=200x200>

# %% [markdown]
# # Croping the image

# %%
img_path = '/content/5.jpeg'
img = cv2.imread(img_path)

# Check if image was loaded successfully
if img is None:
    print(f"Error: Could not load image from {img_path}")
    print("Please check if the file exists and is a valid image format.")
else:
    print(f"Image loaded successfully. Shape: {img.shape}")
    crop = img[220:740,320:970]

    cv2_imshow(img)

    print(crop.shape)
    cv2_imshow(crop)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
# Out:
# Image loaded successfully. Shape: (290, 410, 3)
# <PIL.Image.Image image mode=RGB size=410x290>
# (70, 90, 3)
# <PIL.Image.Image image mode=RGB size=90x70>
