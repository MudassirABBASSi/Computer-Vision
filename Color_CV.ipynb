# %% [markdown]
# <a href="https://colab.research.google.com/github/MudassirABBASSi/Computer-Vision/blob/main/Color_CV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

img_path = "/content/images.jpg"
img = cv2.imread(img_path)

print(img.shape)

img_rgb =cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
img_gbr =cv2.cvtColor(img,cv2.COLOR_BayerGB2GRAY)

cv2_imshow(img)
cv2_imshow(img_gbr)
cv2_imshow(img_rgb)
cv2.waitKey(0)
# Out:
# (262, 192, 3)
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /tmp/ipython-input-2370179634.py in <cell line: 0>()
#       8
#       9 img_rgb =cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
# ---> 10 img_gbr =cv2.cvtColor(img,cv2.COLOR_BayerGB2GRAY)
#      11
#      12 cv2_imshow(img)
#
# error: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/demosaicing.cpp:1763: error: (-215:Assertion failed) scn == 1 && dcn == 1 in function 'demosaicing'

# %%
import cv2
import os
from google.colab.patches import cv2_imshow # Import cv2_imshow

# Use correct image path and ensure it's found
img_path = "/content/images.jpg"
img = cv2.imread(img_path)

# Check if image was loaded successfully
if img is None:
    print(f"Error: Could not load image from {img_path}")
    print("Please check if the file exists and is a valid image format.")
else:
    print(f"Original image shape: {img.shape}")

    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img_GBR = cv2.cvtColor(img, cv2.COLOR_BGR2Lab)
    img_h = cv2.cvtColor(img,cv2.COLOR_BGR2HLS)
    img_f = cv2.cvtColor(img,cv2.COLOR_BGR2HLS_FULL)

    cv2_imshow(img)
    cv2_imshow(img_rgb)
    cv2_imshow(img_gray)
    cv2_imshow(img_GBR)
    cv2_imshow(img_h)
    cv2_imshow(img_f)
# Out:
# Original image shape: (262, 192, 3)
# <PIL.Image.Image image mode=RGB size=192x262>
# <PIL.Image.Image image mode=RGB size=192x262>
# <PIL.Image.Image image mode=L size=192x262>
# <PIL.Image.Image image mode=RGB size=192x262>
# <PIL.Image.Image image mode=RGB size=192x262>
# <PIL.Image.Image image mode=RGB size=192x262>
